# %%
import pandas as pd

# %%
df = pd.read_parquet('data/501c3_charity_geocoded_activities_clean_classified.parquet')

# %%
df
# Out:
#                   EIN2                              CONCATENATED_ACTIVITY  \
# 0       EIN-01-0015091  Provide a travel and recreation soccer platfor...
# 1       EIN-01-0017496  PROVIDES SAILING INSTRUCTION, SEAMAN-SHIP AND ...
# 2       EIN-01-0024645  CONCERTS - THE BSO PRODUCES LIVE CLASSICAL MUS...
# 3       EIN-01-0078060  GOODALL HOSPITAL IS A 58 BED HOSPITAL WHICH ST...
# 4       EIN-01-0085716  No fair held in 2020 because of state mandate ...
# ...                ...                                                ...
# 569503  EIN-99-6064620  PARKER RANCH FOUNDATION TRUST (""PRFT"", THE "...
# 569504  EIN-99-6074970  PROVIDE SCHOLARSHIPS AND GRANTS TO RECIPIENTS ...
# 569505  EIN-99-6078202  THE TRUST GRANTED FUNDS TO THE JOSEPH CAMPBELL...
# 569506  EIN-99-6078252  SEE THE FOLLOWING STATMENTS FOR PROGRAM SERVIC...
# 569507  EIN-99-6086871  DURING THE YEAR, GRANT DISTRIBUTIONS WERE MADE...
#
#         RELIGIOUS_ACTIVITY
# 0                        0
# ...

# %%
df[df['RELIGIOUS_ACTIVITY']==1].CONCATENATED_ACTIVITY.tolist()
# Out:
# ['Our programs provide access to affordable, leading edge educational experiences and resources. We offer innovative opportunities for professional development for ministry leaders - clergy and laity - as well as robust non-degree programs exploring issues of contemporary Christianity & Spirituality in a pluralistic world.',
#  'PROVIDE BIBLES AND SCRIPTURE PORTIONS FOR INDIVIDUALS AND INSTITUTIONS AND PROMOTE BIBLE READING',
#  'IN SUPPORT OF LOCAL SYNAGOGUES AND EDUCATIONAL AND COMMUNITY PROGRAMS',
# ...
