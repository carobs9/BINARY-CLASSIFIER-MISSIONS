# %%
import pandas as pd

# %%
df = pd.read_parquet('data/501c3_charity_geocoded_missions_clean_classified_propmpt2.parquet')

# %%
df
# Out:
#                   EIN2                                  CANONICAL_MISSION  \
# 0       EIN-01-0015091  provide soccer instruction to hanover township...
# 1       EIN-01-0017496  the organization's primary exempt purpose is t...
# 2       EIN-01-0024645  the bangor symphony orchestra provides powerfu...
# 3       EIN-01-0078060  henrietta d goodall hospital inc owns and oper...
# 4       EIN-01-0085716  this corporation hancock county agricultural s...
# ...                ...                                                ...
# 567582  EIN-99-6064620  to provide perpetual support for designated be...
# 567583  EIN-99-6074970  provide scholarships and grants to children an...
# 567584  EIN-99-6078202             philanthropic and educational projects
# 567585  EIN-99-6078252  ""the trustee shall distribute all of the net ...
# 567586  EIN-99-6086871  to distribute amounts to certain charitable or...
#
#         RELIGIOUS
# 0               0
# 1               0
# 2               0
# ...
